# %%
import pandas as pd

ruta = 'C:/Users/Sistemas/Desktop/proyecto_pallets/data/marzo_pallets.xlsx'

df = pd.read_excel (ruta)

df.head()
# Out:
#    Unnamed: 0                        Unnamed: 1  2025-03-01 00:00:00  \
# 0         3.0                        DOZ CARLOS                   24
# 1         5.0                    GARMENDIA HUGO                   38
# 2         8.0                  GRAZIOSI MIRTHA                    20
# 3         9.0  PACI ANTONIO - DIGIANO JAVIER SH                    8
# 4        10.0                    ROSICA GABRIEL                    7
#
#    2025-03-05 00:00:00  2025-03-06 00:00:00  2025-03-07 00:00:00  \
# 0                   20                   19                   24
# 1                   44                   39                   43
# 2                   11                   12                   17
# 3                    9                   11                   10
# 4                    9                    3                    4
#
#    2025-03-08 00:00:00  2025-03-10 00:00:00  2025-03-11 00:00:00  \
# 0                   20                   21                   24
# 1                   45                   45                   51
# 2                   19                   19                   19
# 3                   16                   16                   15
# 4                    7                    8                    5
#
#    2025-03-12 00:00:00  ...  2025-03-29 00:00:00  2025-03-31 00:00:00  \
# 0                   24  ...                   19                   15
# 1                   41  ...                   11                   15
# 2                   26  ...                   42                   42
# 3                   13  ...                    7                    7
# 4                    6  ...                    5                    5
#
#    Unnamed: 25  Promedio pallets por socio diario  \
# 0          NaN                                 19
# 1          NaN                                 35
# 2          NaN                                 28
# 3          NaN                                 10
# 4          NaN                                  6
#
#    Porcentaje pallets por socio  base  Parte variable  Total final por socio  \
# 0                      0.030000    10        9.900000              19.900000
# 1                      0.054945    10       18.131868              28.131868
# 2                      0.043956    10       14.505495              24.505495
# 3                      0.015699    10        5.180534              15.180534
# 4                      0.009419    10        3.108320              13.108320
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                              0.000000                   9
# 1                             -6.868132                  25
# 2                             -3.000000                  18
# 3                              5.000000                   0
# 4                              7.000000                  -4
#
# [5 rows x 33 columns]

# %%
df.rename(columns={'Unnamed: 0': 'id_socio', 'Unnamed: 1': 'socio'}, inplace=True)

# %%
df_melted = pd.melt(df, 
                    id_vars=['id_socio', 'socio'], 
                    value_vars=df.columns[2:24], 
                    var_name='fecha', 
                    value_name='pallets')

# Convertir la columna 'fecha' a tipo datetime
df_melted['fecha'] = pd.to_datetime(df_melted['fecha'])

df_melted.head()
# Out:
#    id_socio                             socio      fecha  pallets
# 0       3.0                        DOZ CARLOS 2025-03-01       24
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7

# %%
# Realizar el merge para asociar las columnas adicionales
df_enriched = pd.merge(df_melted, df[['id_socio', 'socio', 'base', 'Promedio pallets por socio diario', 
                                      'Porcentaje pallets por socio', 'Parte variable', 
                                      'Total final por socio', 'Exceso Palets contra (Fijo+Variable)', 
                                      'Exceso contra Fijo']], 
                       on=['id_socio', 'socio'], 
                       how='left')

df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-03-01       24    10
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8    10
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7    10
#
#    Promedio pallets por socio diario  Porcentaje pallets por socio  \
# 0                                 19                      0.030000
# 1                                 35                      0.054945
# 2                                 28                      0.043956
# 3                                 10                      0.015699
# 4                                  6                      0.009419
#
#    Parte variable  Total final por socio  \
# 0        9.900000              19.900000
# 1       18.131868              28.131868
# 2       14.505495              24.505495
# 3        5.180534              15.180534
# 4        3.108320              13.108320
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                              0.000000                   9
# 1                             -6.868132                  25
# 2                             -3.000000                  18
# 3                              5.000000                   0
# 4                              7.000000                  -4

# %%
df_enriched['Porcentaje pallets por socio'] = df_enriched['Porcentaje pallets por socio'] * 100
df_enriched['Porcentaje pallets por socio'] = df_enriched['Porcentaje pallets por socio'].map('{:.2f}%'.format)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-03-01       24    10
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8    10
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 19                        3.00%
# 1                                 35                        5.49%
# 2                                 28                        4.40%
# 3                                 10                        1.57%
# 4                                  6                        0.94%
#
#    Parte variable  Total final por socio  \
# 0        9.900000              19.900000
# 1       18.131868              28.131868
# 2       14.505495              24.505495
# 3        5.180534              15.180534
# 4        3.108320              13.108320
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                              0.000000                   9
# 1                             -6.868132                  25
# 2                             -3.000000                  18
# 3                              5.000000                   0
# 4                              7.000000                  -4

# %%
df_enriched['Parte variable'] = df_enriched['Parte variable'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-03-01       24    10
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8    10
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 19                        3.00%
# 1                                 35                        5.49%
# 2                                 28                        4.40%
# 3                                 10                        1.57%
# 4                                  6                        0.94%
#
#    Parte variable  Total final por socio  \
# 0               9              19.900000
# 1              18              28.131868
# 2              14              24.505495
# 3               5              15.180534
# 4               3              13.108320
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                              0.000000                   9
# 1                             -6.868132                  25
# 2                             -3.000000                  18
# 3                              5.000000                   0
# 4                              7.000000                  -4

# %%
df_enriched['Total final por socio'] = df_enriched['Total final por socio'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-03-01       24    10
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8    10
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 19                        3.00%
# 1                                 35                        5.49%
# 2                                 28                        4.40%
# 3                                 10                        1.57%
# 4                                  6                        0.94%
#
#    Parte variable  Total final por socio  \
# 0               9                     19
# 1              18                     28
# 2              14                     24
# 3               5                     15
# 4               3                     13
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                              0.000000                   9
# 1                             -6.868132                  25
# 2                             -3.000000                  18
# 3                              5.000000                   0
# 4                              7.000000                  -4

# %%
df_enriched['Exceso Palets contra (Fijo+Variable)'] = df_enriched['Exceso Palets contra (Fijo+Variable)'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-03-01       24    10
# 1       5.0                    GARMENDIA HUGO 2025-03-01       38    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-03-01       20    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-03-01        8    10
# 4      10.0                    ROSICA GABRIEL 2025-03-01        7    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 19                        3.00%
# 1                                 35                        5.49%
# 2                                 28                        4.40%
# 3                                 10                        1.57%
# 4                                  6                        0.94%
#
#    Parte variable  Total final por socio  \
# 0               9                     19
# 1              18                     28
# 2              14                     24
# 3               5                     15
# 4               3                     13
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                                     0                   9
# 1                                    -6                  25
# 2                                    -3                  18
# 3                                     5                   0
# 4                                     7                  -4

# %%
df_enriched.to_excel('df_melted_exportado.xlsx', index=False)
