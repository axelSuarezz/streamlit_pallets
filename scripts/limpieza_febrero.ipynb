# %%
import pandas as pd

ruta = 'C:/Users/Sistemas/Desktop/proyecto_pallets/data/febrero_pallets.xlsx'

df = pd.read_excel (ruta)

df.head()
# Out:
#    Unnamed: 0                        Unnamed: 1  2025-02-03 00:00:00  \
# 0         3.0                        DOZ CARLOS                   13
# 1         5.0                    GARMENDIA HUGO                   67
# 2         8.0                  GRAZIOSI MIRTHA                    39
# 3         9.0  PACI ANTONIO - DIGIANO JAVIER SH                    8
# 4        10.0                    ROSICA GABRIEL                   11
#
#    2025-02-04 00:00:00  2025-02-05 00:00:00  2025-02-06 00:00:00  \
# 0                   13                   19                   25
# 1                   63                   59                   54
# 2                   39                   46                   48
# 3                   10                    9                    9
# 4                   11                   14                   10
#
#    2025-02-07 00:00:00  2025-02-08 00:00:00  2025-02-12 00:00:00  \
# 0                   22                   25                   31
# 1                   63                   64                   46
# 2                   51                   53                   50
# 3                    8                    5                   12
# 4                   14                    6                   13
#
#    2025-02-13 00:00:00  ...  2025-02-27 00:00:00  2025-02-28 00:00:00  \
# 0                   30  ...                   37                   31
# 1                   30  ...                   43                   27
# 2                   44  ...                   23                   23
# 3                    8  ...                    9                    9
# 4                    1  ...                   13                   14
#
#    Unnamed: 23  Promedio pallets por socio diario  \
# 0          NaN                                 27
# 1          NaN                                 48
# 2          NaN                                 37
# 3          NaN                                 10
# 4          NaN                                  8
#
#    Porcentaje pallets por socio  base  Parte variable  Total final por socio  \
# 0                      0.040971    10       13.520486              23.520486
# 1                      0.072838    10       24.036419              34.036419
# 2                      0.056146    10       18.528073              28.528073
# 3                      0.015175    10        5.007587              15.007587
# 4                      0.012140    10        4.006070              14.006070
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                             -3.479514                  17
# 1                            -13.963581                  38
# 2                             -8.471927                  27
# 3                              5.007587                   0
# 4                              6.006070                  -2
#
# [5 rows x 31 columns]

# %%
df.rename(columns={'Unnamed: 0': 'id_socio', 'Unnamed: 1': 'socio'}, inplace=True)

# %%
df_melted = pd.melt(df, 
                    id_vars=['id_socio', 'socio'], 
                    value_vars=df.columns[2:23], 
                    var_name='fecha', 
                    value_name='pallets')

# Convertir la columna 'fecha' a tipo datetime
df_melted['fecha'] = pd.to_datetime(df_melted['fecha'])

df_melted.head()
# Out:
#    id_socio                             socio      fecha  pallets
# 0       3.0                        DOZ CARLOS 2025-02-03       13
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11

# %%
# Realizar el merge para asociar las columnas adicionales
df_enriched = pd.merge(df_melted, df[['id_socio', 'socio', 'base', 'Promedio pallets por socio diario', 
                                      'Porcentaje pallets por socio', 'Parte variable', 
                                      'Total final por socio', 'Exceso Palets contra (Fijo+Variable)', 
                                      'Exceso contra Fijo']], 
                       on=['id_socio', 'socio'], 
                       how='left')

df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-02-03       13    10
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8    10
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11    10
#
#    Promedio pallets por socio diario  Porcentaje pallets por socio  \
# 0                                 27                      0.040971
# 1                                 48                      0.072838
# 2                                 37                      0.056146
# 3                                 10                      0.015175
# 4                                  8                      0.012140
#
#    Parte variable  Total final por socio  \
# 0       13.520486              23.520486
# 1       24.036419              34.036419
# 2       18.528073              28.528073
# 3        5.007587              15.007587
# 4        4.006070              14.006070
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                             -3.479514                  17
# 1                            -13.963581                  38
# 2                             -8.471927                  27
# 3                              5.007587                   0
# 4                              6.006070                  -2

# %%
df_enriched['Porcentaje pallets por socio'] = df_enriched['Porcentaje pallets por socio'] * 100
df_enriched['Porcentaje pallets por socio'] = df_enriched['Porcentaje pallets por socio'].map('{:.2f}%'.format)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-02-03       13    10
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8    10
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 27                        4.10%
# 1                                 48                        7.28%
# 2                                 37                        5.61%
# 3                                 10                        1.52%
# 4                                  8                        1.21%
#
#    Parte variable  Total final por socio  \
# 0       13.520486              23.520486
# 1       24.036419              34.036419
# 2       18.528073              28.528073
# 3        5.007587              15.007587
# 4        4.006070              14.006070
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                             -3.479514                  17
# 1                            -13.963581                  38
# 2                             -8.471927                  27
# 3                              5.007587                   0
# 4                              6.006070                  -2

# %%
df_enriched['Parte variable'] = df_enriched['Parte variable'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-02-03       13    10
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8    10
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 27                        4.10%
# 1                                 48                        7.28%
# 2                                 37                        5.61%
# 3                                 10                        1.52%
# 4                                  8                        1.21%
#
#    Parte variable  Total final por socio  \
# 0              13              23.520486
# 1              24              34.036419
# 2              18              28.528073
# 3               5              15.007587
# 4               4              14.006070
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                             -3.479514                  17
# 1                            -13.963581                  38
# 2                             -8.471927                  27
# 3                              5.007587                   0
# 4                              6.006070                  -2

# %%
df_enriched['Total final por socio'] = df_enriched['Total final por socio'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-02-03       13    10
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8    10
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 27                        4.10%
# 1                                 48                        7.28%
# 2                                 37                        5.61%
# 3                                 10                        1.52%
# 4                                  8                        1.21%
#
#    Parte variable  Total final por socio  \
# 0              13                     23
# 1              24                     34
# 2              18                     28
# 3               5                     15
# 4               4                     14
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                             -3.479514                  17
# 1                            -13.963581                  38
# 2                             -8.471927                  27
# 3                              5.007587                   0
# 4                              6.006070                  -2

# %%
df_enriched['Exceso Palets contra (Fijo+Variable)'] = df_enriched['Exceso Palets contra (Fijo+Variable)'].astype(int)
df_enriched.head()
# Out:
#    id_socio                             socio      fecha  pallets  base  \
# 0       3.0                        DOZ CARLOS 2025-02-03       13    10
# 1       5.0                    GARMENDIA HUGO 2025-02-03       67    10
# 2       8.0                  GRAZIOSI MIRTHA  2025-02-03       39    10
# 3       9.0  PACI ANTONIO - DIGIANO JAVIER SH 2025-02-03        8    10
# 4      10.0                    ROSICA GABRIEL 2025-02-03       11    10
#
#    Promedio pallets por socio diario Porcentaje pallets por socio  \
# 0                                 27                        4.10%
# 1                                 48                        7.28%
# 2                                 37                        5.61%
# 3                                 10                        1.52%
# 4                                  8                        1.21%
#
#    Parte variable  Total final por socio  \
# 0              13                     23
# 1              24                     34
# 2              18                     28
# 3               5                     15
# 4               4                     14
#
#    Exceso Palets contra (Fijo+Variable)  Exceso contra Fijo
# 0                                    -3                  17
# 1                                   -13                  38
# 2                                    -8                  27
# 3                                     5                   0
# 4                                     6                  -2

# %%
df_enriched.to_excel('febrero_limpio.xlsx', index=False)
